# %%
import pandas as pd
import numpy as np
import matplotlib as mt
    
#sedikit improvisasi, aku pakai validasi try

try:
    df = pd.read_csv("dataset/diabetes.csv")
    print("Data berhasil di dapatkan")
except FileNotFoundError:
    print("data tidak ditemukan")
# Out:
# Data berhasil di dapatkan

# %%
df.head()#df.head itu untuk buat menampilkan 5 data pertama
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.head(10)#tambahkan kurung di dalam untuk menampilan data sesuai dengan yang kita inginkan
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
df.tail()#menampilkan 5 data akhir
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.tail(10)#tambahkan kurung di dalam untuk menampilan data sesuai dengan yang kita inginkan
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
df.describe() #menjelaskan dataset nya, dari total datanya, mean, standard deviasi, max , dan persentase
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.describe(percentiles=[0.2,0.6,0.9]) #memodifikasi persentase nya
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 20%       1.000000   95.000000      60.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 60%       4.000000  125.000000      74.000000      27.000000   72.200000
# 90%       9.000000  167.000000      88.000000      40.000000  210.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# ...

# %%
df.describe(include=[int,float]) #ini pengelompokkan data, jadi kita bisa memasukkan data nya mau ada interger atau float
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.describe(exclude=[float]) #sama, tapi bedanya kita mengeluarkan data yang punya float, intinya sesuai yang kita masukkan
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               Age     Outcome
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %%
df.describe().T #memindahkan, menukar, atau mengubah posisi dari kolom tabel menjadi baris tabel, baris tabel jadi kolom tabel
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
df.info(show_counts=True, memory_usage=True, verbose=True) 
#info() adalah cara cepat untuk melihat tipe data, nilai yang hilang, dan ukuran data dari sebuah DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.shape # Get the number of rows and columns
# Out:
# (768, 9)

# %%
df.shape[0] # Get the number of rows only
# Out:
# 768

# %%
df.shape[1] # Get the number of columns only
# Out:
# 9

# %%
df.columns #lihat kolom yang ada di dataset
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
list(df.columns) #lihat kolom dali list
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
df2 = df.copy()
df2.loc[2:5,'Pregnancies'] = None
df2.head(7)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72             35        0  33.6
# 1          1.0       85             66             29        0  26.6
# 2          NaN      183             64              0        0  23.3
# 3          NaN       89             66             23       94  28.1
# 4          NaN      137             40             35      168  43.1
# 5          NaN      116             74              0        0  25.6
# 6          3.0       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1

# %%
df2.info(show_counts=True, memory_usage=True, verbose=True) #lihat informasi data yang sudah di kosongkan
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               764 non-null    float64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(3), int64(6)
# memory usage: 54.1 KB

# %%
df2.isnull().head(7) #bisa check kekosongan data pakai isnull, tunjukkannya itu true and false
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0        False    False          False          False    False  False
# 1        False    False          False          False    False  False
# 2         True    False          False          False    False  False
# 3         True    False          False          False    False  False
# 4         True    False          False          False    False  False
# 5         True    False          False          False    False  False
# 6        False    False          False          False    False  False
#
#    DiabetesPedigreeFunction    Age  Outcome
# 0                     False  False    False
# 1                     False  False    False
# 2                     False  False    False
# 3                     False  False    False
# 4                     False  False    False
# 5                     False  False    False
# 6                     False  False    False

# %%
df2.isnull().sum() #atau check hitungan total missing values nya nya
# Out:
# Pregnancies                 4
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.sort_values(by="Age", ascending=False, inplace=False) # Sort by Age in descending order
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 459            9      134             74             33       60  25.9
# 453            2      119              0              0        0  19.6
# 666            4      145             82             18        0  32.5
# 684            5      136             82              0        0   0.0
# 123            5      132             80              0        0  26.8
# ..           ...      ...            ...            ...      ...   ...
# 525            3       87             60             18        0  21.8
# 626            0      125             68              0        0  24.7
# 511            0      139             62             17      210  22.1
# 156            2       99             52             15       94  24.6
# 580            0      151             90             46        0  42.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 459                     0.460   81        0
# ...

# %%
df.sort_values(by=["Age","Glucose"], ascending=[True, False], inplace=False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 220            0      177             60             29      478  34.6
# 580            0      151             90             46        0  42.1
# 413            1      143             74             22       61  26.2
# 94             2      142             82             18       64  24.7
# 486            1      139             62             41      480  40.7
# ..           ...      ...            ...            ...      ...   ...
# 684            5      136             82              0        0   0.0
# 123            5      132             80              0        0  26.8
# 666            4      145             82             18        0  32.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 220                     1.072   21        1
# ...

# %%
#menyaring data menggunakan konsidi
df[df["BloodPressure"] >100] #menunjukkan data dari kolom bloodpressure yang lebih dari 100
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 177            0      129            110             46      130  67.1
# 106            1       96            122              0        0  22.4
# 84             5      137            108              0        0  48.8
# 549            4      189            110             31        0  28.5
# 440            0      189            104             25        0  34.3
# 662            8      167            106             46      231  37.6
# 691           13      158            114              0        0  42.3
# 369            1      133            102             28      140  32.8
# 672           10       68            106             23       49  35.5
# 658           11      127            106              0        0  39.0
# 207            5      162            104              0        0  37.7
# 43             9      171            110             24      240  45.4
# ...

# %%
#Isolating one column using [ ]
df[["Outcome","BloodPressure"]].head(10)
# Out:
#      Outcome  BloodPressure
# 371        0             64
# 392        0             64
# 414        1             60
# 208        0             64
# 413        0             74
# 423        0             64
# 182        0             74
# 486        0             62
# 200        0             80
# 196        0             58

# %%
#Isolating one column using [ ]
df[["Pregnancies","Outcome"]]
# Out:
#      Pregnancies  Outcome
# 0              6        1
# 1              1        0
# 2              8        1
# 3              1        0
# 4              0        1
# ..           ...      ...
# 763           10        0
# 764            2        0
# 765            5        0
# 766            1        1
# 767            1        0
#
# [768 rows x 2 columns]

# %%
df[df.index==767] #ngambil 1 data pakai index
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 767                     0.315   23        0

# %%
df[df.index.isin(range(1,10))] #mengambil data index lebih dari 1.
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# ...

# %%
df.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0            0.0      0.0  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %%
df.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df['Pregnancies'].value_counts()
# Out:
# np.int64(768)

# %%
df['Outcome'].value_counts(normalize=True)

# %%
df['Outcome'].value_counts(sort=False) #sorting is based on the counts in descending order.
# Out:
# Outcome
# 1    268
# 0    500
# Name: count, dtype: int64

# %%
df.value_counts(subset=['Pregnancies', 'Outcome'])
#You can also apply .value_counts() to a DataFrame object and specific columns within it instead of just a column. Here, for example, we are applying value_counts() on df with the subset argument, which takes in a list of columns.

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
df.groupby(['Pregnancies', 'Outcome']).mean()
# Out:
#                         Glucose  BloodPressure  SkinThickness     Insulin  \
# Pregnancies Outcome
# 0           0        111.945205      69.205479      21.054795   77.561644
#             1        144.236842      63.210526      24.605263   89.578947
# 1           0        104.254717      66.830189      23.047170   84.320755
#             1        143.793103      71.310345      29.517241  151.137931
# 2           0        105.214286      61.940476      20.107143   72.619048
#             1        135.473684      69.052632      28.210526  144.315789
# 3           0        109.604167      65.708333      17.520833   62.020833
#             1        148.444444      68.148148      24.629630  132.666667
# 4           0        117.555556      71.577778      18.422222   78.466667
#             1        139.913043      67.000000      10.913043   51.782609
# 5           0        111.666667      74.666667      17.166667   46.861111
# ...

# %%
df[['BMI', 'Glucose']].plot.line()
# Out:
# <Axes: >

# %%
df[['BMI', 'Glucose']].plot.line(figsize=(20, 10), 
                                 color={"BMI": "green", "Glucose": "cyan"})
# Out:
# <Axes: >

# %%
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df['Outcome'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Outcome'>

# %%
df.boxplot(column=['BMI'], by='Outcome')
# Out:
# <Axes: title={'center': 'BMI'}, xlabel='Outcome'>
